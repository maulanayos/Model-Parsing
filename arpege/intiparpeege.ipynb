# %%
import xarray as xr

# %%
ds = xr.open_dataset('/mnt/data/output/arpege/arpege_20240214_1800.nc')

# %%
ds['wdir'][:,2,10,10].plot()

# %%
ds['u'].attrs['units'] = 'm s**-1'
ds['v'].attrs['units'] = 'm s**-1'

# %%
from metpy.calc import wind_direction

# %%
wdir = wind_direction(ds['u'], ds['v'])

# %%
type(wdir)
# Out:
# pint.quantity.build_quantity_class.<locals>.Quantity
