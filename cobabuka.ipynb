# %%
f = '/mnt/data/output/gfs_indo_v2/2023/12/gfs_20231206_0000.nc'
# f = '/mnt/data/output/gfs_indo/2023/11/gfs_20231101_0000.nc'

# %%
import xarray as xr

ds = xr.open_dataset(f)
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (lat: 261, level: 15, lon: 401, time: 120)
# Coordinates:
#   * lon              (lon) float64 70.0 70.25 70.5 70.75 ... 169.5 169.8 170.0
#   * lat              (lat) float64 -25.0 -24.75 -24.5 -24.25 ... 39.5 39.75 40.0
#   * level            (level) float64 100.0 150.0 200.0 ... 925.0 950.0 1e+03
#   * time             (time) datetime64[ns] 2023-12-06T01:00:00 ... 2023-12-11
# Data variables:
#     rh2              (time, lat, lon) float64 ...
#     t2               (time, lat, lon) float64 ...
#     u10              (time, lat, lon) float64 ...
#     v10              (time, lat, lon) float64 ...
#     vis              (time, lat, lon) float64 ...
#     gust             (time, lat, lon) float64 ...
#     prate            (time, lat, lon) float64 ...
#     rr               (time, lat, lon) float64 ...
#     lftx             (time, lat, lon) float64 ...
#     cape             (time, lat, lon) float64 ...
# ...

# %%
ds['level']
# Out:
# <xarray.DataArray 'level' (level: 15)>
# array([1000.,  950.,  925.,  900.,  850.,  800.,  700.,  600.,  500.,  400.,
#         300.,  250.,  200.,  150.,  100.])
# Coordinates:
#   * level    (level) float64 1e+03 950.0 925.0 900.0 ... 250.0 200.0 150.0 100.0
# Attributes:
#     units:      mbar
#     long_name:  isobaric level

# %%
ds.sel(lon = 110, lat =0)['rh2'].plot()

# %%
ds['u'][:,14,50,0].plot()
